# %% [markdown]
# # Recommender Systems 3 - Content-based Filtering

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import string
from pprint import pprint
from random import randrange
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Load data

# %%
all_songs = pd.read_csv('data/songdata.csv')
all_songs.shape
# Out:
# (57650, 4)

# %%
pd.set_option('max_colwidth', 100)

# %%
# Display first few rows
all_songs.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                                                                   text
# 0  Look at her face, it's a wonderful face  \nAnd it means something special to me  \nLook at the w...
# 1  Take it easy with me, please  \nTouch me gently like a summer evening breeze  \nTake your time, ...
# 2  I'll never know why I had to go  \nWhy I had to put up such a lousy rotten show  \nBoy, I was to...
# 3  Making somebody happy is a question of give and take  \nYou can learn how to show it so come on,...
# 4  Making somebody happy is a question of give and take  \nYou can learn how to show it so come on,...

# %% [markdown]
# ### Set global variables

# %%
global test_song

# %% [markdown]
# ### Preprocess data

# %%
# Prepare smaller data subset of 5000 randomly selected songs, and drop column 'link'
songs = all_songs.sample(n=5000).drop('link', axis=1).reset_index(drop=True)
songs.head()
# Out:
#                artist               song  \
# 0        Bill Withers  Hello Like Before
# 1       Ozzy Osbourne         Psycho Man
# 2  Marianne Faithfull     As Tears Go By
# 3                Cher    Dressed To Kill
# 4            Iggy Pop   Plastic Concrete
#
#                                                                                                   text
# 0  Hello like before  \nI'd never come here  \nIf I'd known that you were here  \nI must admit thou...
# 1  The midnight hour approaches  \nThe killing chill takes over him  \nHis victims will not know  \...
# 2  It is the evening of the day,  \nI sit and watch the children play.  \nSmiling faces I can see  ...
# 3  I slip into my shoes and slide into the night  \nI'm on the loose, you're in my sights  \nYou kn...
# 4  Plastic and concrete, baby  \nThese are the facts of life  \nI'm a nightmare child  \nStuck on m...

# %%
# Randomly select a test song
test_song = randrange(5000)     # Select an integer between 0 and 4999
print(test_song)
print(songs['artist'][test_song])
print(songs['song'][test_song])
# Out:
# 4758
# Celine Dion
# All The Way

# %%
# Display text (lyrics) for test song
songs['text'][test_song]
# Out:
# "When somebody loves you  \nIt's no good unless he loves you all the way  \nHappy to be near you  \nWhen you need someone to cheer you all the way  \n  \nTaller than the tallest tree is  \nThat's how it's got to feel  \nDeeper than the deep blue sea is  \nThat's how deep it goes if its real  \n  \nWhen somebody needs you  \nIt's no good unless he needs you all the way  \nThrough the good or lean years  \nAnd for all the in between years, come what way  \n  \nWho know where the road will lead us  \nOnly a fool would say  \nBut if you'll let me love you  \nIt's for sure I'm gonna love you, all the way, all the way\n\n"

# %%
# Clean-up data: remove newline characters
songs['text'] = songs['text'].str.replace(r'\n', '', regex=True)
songs.head()
# Out:
#                artist               song  \
# 0        Bill Withers  Hello Like Before
# 1       Ozzy Osbourne         Psycho Man
# 2  Marianne Faithfull     As Tears Go By
# 3                Cher    Dressed To Kill
# 4            Iggy Pop   Plastic Concrete
#
#                                                                                                   text
# 0  Hello like before  I'd never come here  If I'd known that you were here  I must admit though  Th...
# 1  The midnight hour approaches  The killing chill takes over him  His victims will not know  When ...
# 2  It is the evening of the day,  I sit and watch the children play.  Smiling faces I can see  But ...
# 3  I slip into my shoes and slide into the night  I'm on the loose, you're in my sights  You know i...
# 4  Plastic and concrete, baby  These are the facts of life  I'm a nightmare child  Stuck on my own ...

# %%
# Create function to remove punctuation and lowercase all text
def cleanup_text(text):
    text = "".join([word.lower() for word in text if word not in string.punctuation])
    return text

# Remove punctuation and lowercase all text
songs['text'] = songs['text'].apply(lambda x: cleanup_text(x))

# %%
# Display text (lyrics) for same song after cleaning
songs['text'][test_song]
# Out:
# 'when somebody loves you  its no good unless he loves you all the way  happy to be near you  when you need someone to cheer you all the way    taller than the tallest tree is  thats how its got to feel  deeper than the deep blue sea is  thats how deep it goes if its real    when somebody needs you  its no good unless he needs you all the way  through the good or lean years  and for all the in between years come what way    who know where the road will lead us  only a fool would say  but if youll let me love you  its for sure im gonna love you all the way all the way'

# %% [markdown]
# ### Run TF-IDF vectorizer

# %%
# Calculate the TF-IDF score for each song lyric, word by word
tfidf = TfidfVectorizer(analyzer='word', stop_words='english')

# Create a lyric_matrix variable where we store the matrix
#  containing each word and its TF-IDF score with regard to each song lyric
lyrics_matrix = tfidf.fit_transform(songs['text'])
lyrics_matrix
# Out:
# <5000x26297 sparse matrix of type '<class 'numpy.float64'>'
# 	with 277676 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Generate lyrics matrix to make recommendations

# %%
# Calculate the cosine similarity of each item with every other item in the dataset
cosine_similarities = cosine_similarity(lyrics_matrix)
cosine_similarities.shape
# Out:
# (5000, 5000)

# %%
cosine_similarities
# Out:
# array([[1.00000000e+00, 4.58948433e-04, 1.27182549e-02, ...,
#         5.33922667e-02, 6.10744149e-03, 4.36415745e-02],
#        [4.58948433e-04, 1.00000000e+00, 1.43500038e-03, ...,
#         1.22254415e-03, 3.27296391e-04, 5.55850464e-04],
#        [1.27182549e-02, 1.43500038e-03, 1.00000000e+00, ...,
#         6.65594659e-03, 7.19727664e-04, 1.68154576e-03],
#        ...,
#        [5.33922667e-02, 1.22254415e-03, 6.65594659e-03, ...,
#         1.00000000e+00, 3.20819971e-03, 1.38451302e-02],
#        [6.10744149e-03, 3.27296391e-04, 7.19727664e-04, ...,
#         3.20819971e-03, 1.00000000e+00, 1.11032696e-02],
#        [4.36415745e-02, 5.55850464e-04, 1.68154576e-03, ...,
#         1.38451302e-02, 1.11032696e-02, 1.00000000e+00]])

# %%
# Print sample cosine_similarities row
cosine_similarities[test_song]
# Out:
# array([0.03366853, 0.00842925, 0.        , ..., 0.0088328 , 0.00928133,
#        0.02914885])

# %%
# Print index values for sample cosine_similarities row
#    argsort performs an indirect sort on a numpy array
#    It returns an array of indicies in sorted order
cosine_similarities[test_song].argsort()
# Out:
# array([4444, 2067, 2061, ..., 2895, 3864, 4758])

# %%
# Print top 10 indicies from sample cosine_similarities row in descending sorted order
cosine_similarities[test_song].argsort()[:-10:-1]
# Out:
# array([4758, 3864, 2895, 4725, 2410, 2054, 2162, 2699, 2793])

# %%
# %%time

# Store the names of the 50 most similar songs for each song in our dataset
similarities = {}
for i in range(len(cosine_similarities)):
    # Sort each element in cosine_similarities and get the indexes of the 50 most similar songs
    similar_indices = cosine_similarities[i].argsort()[:-50:-1]
    
    # Store in similarities each name of the 50 most similar songs
    # Note: the first one is the same song
    similarities[songs['song'].iloc[i]] = [(cosine_similarities[i][x], songs['song'][x], songs['artist'][x])
                                           for x in similar_indices][1:]

similarities
# Out:
# CPU times: user 3.72 s, sys: 51.6 ms, total: 3.77 s
# Wall time: 3.84 s
# {'Hello Like Before': [(0.4378653779832861, 'Hello Goodbye', 'Paul McCartney'),
#   (0.43234449794684093, 'Smells Like Teen Spirit (Live)', 'Avril Lavigne'),
#   (0.3772149070256412,
#    "Hello, I Love You (Let's Get Tested For AIDS)",
#    'Bob Rivers'),
#   (0.37605977261296675, 'I Guess I Like It Like That', 'Kylie Minogue'),
#   (0.29943890108565957, 'Hello, Young Lovers', 'The Temptations'),
#   (0.2693046819928457, 'Something', 'Drake'),
#   (0.24308409037536033, "I Don't Wanna Know", 'Indigo Girls'),
#   (0.23351439945192637, 'Leaves That Are Green', 'Paul Simon'),
#   (0.22767579266036705, 'Heroin', 'Lou Reed'),
#   (0.21784269491725466, 'If We Ever Meet Again', 'Katy Perry'),
#   (0.20742456615883167, 'After All', 'Cher'),
#   (0.2026641821327671, 'Doing Fine', 'Cliff Richard'),
#   (0.20085707813803483, 'Propinquity', 'Nitty Gritty Dirt Band'),
#   (0.1977732817960481, 'Goodbye Sam - Hello Samantha', 'Cliff Richard'),
#   (0.1821669798183236, 'Last To Know', 'P!nk'),
#   (0.1806848041903198, "Guess I'm Falling In Love", 'Velvet Underground'),
#   (0.1764879641652966, 'On And On', 'Inna'),
#   (0.17496063142478846, 'Funny How Time Slips Away', 'Johnny Cash'),
#   (0.1699762856641896, 'On Broken Wings', 'Europe'),
#   (0.1682333897965934, 'A Different Point Of View', 'Pet Shop Boys'),
#   (0.16653077578892891, 'You Were There', 'Regine Velasquez'),
#   (0.16557745639066182, "I'd Like To Dial Your Number", 'Marianne Faithfull'),
#   (0.16380083083002583, 'Homecoming', 'Kanye West'),
#   (0.16085560149673617, 'I Wish I Could Say That', 'Kenny Rogers'),
#   (0.15954652729457197, 'Growing Up', 'Fall Out Boy'),
#   (0.15898680026199122, 'I Hope So', 'Willie Nelson'),
#   (0.15529225226834734, 'What I Like About You', 'Poison'),
#   (0.15166349221156805, 'So Serious', 'Electric Light Orchestra'),
#   (0.149951543564994, 'Forever', 'Omd'),
#   (0.14985964958543585, 'Funny How Time Slips Away', 'Elvis Presley'),
#   (0.14985964958543585, 'Funny How Time Slips Away', 'Tina Turner'),
#   (0.14945094885249818, "I Just Thought You'd Like To Know", 'Johnny Cash'),
#   (0.14906128789717935, 'Happy? - Intwine', 'HIM'),
#   (0.14831560859895795, 'The Children', 'Starship'),
#   (0.1471981889704046, 'Moment Of Forgiveness', 'Indigo Girls'),
#   (0.1429466534706654, 'Sunshine', 'Vertical Horizon'),
#   (0.14240151015273186, 'Goodnight', 'John Mellencamp'),
#   (0.1412181188709153, 'Redemption', 'Inside Out'),
#   (0.1393454108003751, 'Do What You Gotta Do', 'Nina Simone'),
#   (0.1383373206908063, 'Could It Be You?', "'n Sync"),
#   (0.13806741114289348, 'Red Line', 'The Broadways'),
#   (0.13681497550466526, 'Here I Go Again', 'Whitesnake'),
#   (0.13448813857734343, 'Goodbye Kiss', 'Lana Del Rey'),
#   (0.134206459596877, 'Some Children See Him', 'James Taylor'),
#   (0.1328280820751686, 'Feels Like Home', 'Bonnie Raitt'),
#   (0.13220552400796431, 'God', 'Outkast'),
#   (0.13071013023506234, 'Mr. What I Wanna Be', 'Freestyle'),
#   (0.13030126480392573, 'Break Me Shake Me', 'Savage Garden')],
#  'Psycho Man': [(0.42163268316516866, 'Psycho Therapy', 'Ramones'),
#   (0.3868916146453461, 'Looking For An Angel', 'Kylie Minogue'),
#   (0.3775114308227734, 'Be An Angel', 'Dean Martin'),
#   (0.35356979482670814, 'American Psycho', 'Misfits'),
#   (0.33991746216550156, 'You Love Me To Death', 'Hooverphonic'),
#   (0.2848257819365996, 'Psycho Circus', 'Kiss'),
#   (0.2807934470176774, 'Angel Of Mercy', 'Dire Straits'),
#   (0.24655586694095655, 'Mother Of Mercy', 'Iron Maiden'),
#   (0.24260970010185384, 'Blood On Stone', 'Uriah Heep'),
#   (0.2282176576301189, 'Angel', 'Rod Stewart'),
#   (0.22061684847971788, 'Guardian Angel', 'Lou Reed'),
#   (0.21902373103801237, 'Scared To Death', 'HIM'),
#   (0.21777297383007235, 'Fate Of Man', 'Glen Campbell'),
#   (0.21616296358483325, 'Angel In The Christmas Play', 'Carpenters'),
#   (0.20881042749159134, 'A Runner With The Pack', 'Donna Summer'),
#   (0.20486207329179906, 'Death Is Not The End', 'Kylie Minogue'),
#   (0.20403991115403153, 'Death Or Glory', 'Clash'),
#   (0.20252842595037313, 'Angel Of The Morning', 'Nina Simone'),
#   (0.2022900612837596, 'Bring It All Together', 'Natalie Grant'),
#   (0.19226666152256344, "Can't Help Lovin' Dat Man", 'Ella Fitzgerald'),
#   (0.1858155258269591, 'Send Me An Angel', 'Scorpions'),
#   (0.1835836573470059, "Maybe I'm Right", 'Linda Ronstadt'),
#   (0.18197812608084452, 'Man On The Corner', 'Genesis'),
#   (0.17537552906797174, 'Juarez', 'Tori Amos'),
#   (0.16809270268538615, 'Angel', 'Lionel Richie'),
#   (0.16742358567669638, 'Man To Man', 'Joni Mitchell'),
#   (0.1636257461613835, 'The Guaranteed Eternal Sanctuary Man', 'Genesis'),
#   (0.16175630207061148, 'No One Told Him', 'Thin Lizzy'),
#   (0.15887018766180896, 'Nowhere Man', 'The Beatles'),
#   (0.15872556329033177, 'An Angel', 'Kelly Family'),
#   (0.15300866662940732, "Junkie's Lament", 'Indigo Girls'),
#   (0.152605844173285, "I'm Waiting For The Man", 'Lou Reed'),
#   (0.14988526929811147, "He's Alive", 'Dolly Parton'),
#   (0.1492799655365296, 'I Want Be Man', 'Cheap Trick'),
#   (0.1479599874321048, 'Mr. What I Wanna Be', 'Freestyle'),
#   (0.14762765906585873, "I Wouldn't Change The Man He Is", 'Diana Ross'),
#   (0.14754019176269317,
#    "A Little Heaven's Rubbing Off On Me",
#    'George Strait'),
#   (0.14492420433064418, 'Soldier Side', 'System Of A Down'),
#   (0.14305149613199672, 'Death Of A Clown', 'Kinks'),
#   (0.14297043092500133, 'For You', 'Lana Del Rey'),
#   (0.14048999555267416, 'Just A Name', 'Cher'),
#   (0.13698238037987157, 'Bad Luck', 'U. D. O.'),
#   (0.13522676727105992, "He Ain't Heavy...He's My Brother", 'Cher'),
#   (0.13516783000533428, 'Still (In Control)', 'Kirk Franklin'),
#   (0.13387062030053612, 'I Would', 'One Direction'),
#   (0.1337849804261257, "God's Top Ten", 'INXS'),
#   (0.13338820565316895, "He's A Liar", 'Bee Gees'),
#   (0.13133122743668785, "Walkin' In The Sun", 'Chaka Khan')],
#  'As Tears Go By': [(0.7817493150904345, 'Little Darling', 'Indigo Girls'),
#   (0.34397091222375653, 'Love And Kisses', 'Natalie Cole'),
#   (0.17917841633945727, 'Little Girl Blue', 'Janis Joplin'),
#   (0.13494936181937275,
#    'Girls Were Made To Take Care Of Boys',
#    'Billie Holiday'),
#   (0.13165339322860167, 'The Squid', 'Zox'),
#   (0.11065071484914554, "Don't Send Me Away", 'The Temptations'),
#   (0.10989022297238803, 'Calling You', 'Natalie Cole'),
#   (0.09395932121310617, 'Give It Away', 'George Strait'),
#   (0.0699902260694237, 'Hot Revolver', 'Lil Wayne'),
#   (0.0641657389861731, 'Miss Right', 'Ne-Yo'),
#   (0.06004798345260422, 'Brand New', 'Lil Wayne'),
#   (0.05773185276707237, 'Falling Out Of Love With Me', 'Dolly Parton'),
#   (0.052590197970304, 'The Children', 'Starship'),
#   (0.04918201705405368, 'Music Of My Heart', "'n Sync"),
#   (0.04687075086452039, 'Me And Bobby Mcgee', 'Gordon Lightfoot'),
#   (0.04580074034592918, 'The Assassin', 'Iron Maiden'),
#   (0.04303099478754057, 'Gangbang Rookie', 'Snoop Dogg'),
#   (0.04295033978025199, 'Children Of The Damned', 'Iron Maiden'),
#   (0.0396834704766875, 'Some Children See Him', 'James Taylor'),
#   (0.03631095531249549, 'American Music', 'Ian Hunter'),
#   (0.03515000320816447, 'A Beautiful Story', 'Cher'),
#   (0.03360584298924081, 'Same Old Blues', 'Freddie King'),
#   (0.03331588165726446, 'Galway Bay', 'John McDermott'),
#   (0.03277476042685252, 'My Favorite Headache', 'Rush'),
#   (0.03251155793729646, 'Prayer Of The Children', 'Inside Out'),
#   (0.0324833540253136, 'Barefoot Children', 'Jimmy Buffett'),
#   (0.03170598713168071, 'Green Eyes', 'Conway Twitty'),
#   (0.03141661891800525, 'Hold On', 'Kim Wilde'),
#   (0.03109235302246556,
#    "I'm Gonna Sit Right Down And Write Myself A Letter",
#    'Perry Como'),
#   (0.030383250006549928,
#    'When She Wakes Up (And Finds Me Gone)',
#    'Tim McGraw'),
#   (0.02987046262031168, "Can't We Just Sit Down", 'Donna Summer'),
#   (0.028367559453948477, "A Bird's Song", 'Ingrid Michaelson'),
#   (0.027664928273329833, 'Subculture', 'New Order'),
#   (0.027395513063778593, "For What It's Worth", 'Marianne Faithfull'),
#   (0.027298765508141247, 'Out On Patrol', 'Offspring'),
#   (0.027082348415314598, 'Children On Parade', 'Men At Work'),
#   (0.02698850953314147, 'Colours', 'Phil Collins'),
#   (0.025783282086389633, 'Teardrops Will Fall', 'John Mellencamp'),
#   (0.025648567346084387, 'Life In A Glass House', 'Radiohead'),
#   (0.025349857084063995, 'Let Go', 'Ne-Yo'),
#   (0.02521168037500667, 'Straight Edge', 'NOFX'),
#   (0.025101062909751774, 'I Can Hear My Heart Break', 'Conway Twitty'),
#   (0.02482887523720058, '12', 'Insane Clown Posse'),
#   (0.02432925568652808, 'Be Me 4 A Day', 'Michael Jackson'),
#   (0.024167322909496337, 'Fingerprints', 'Patsy Cline'),
#   (0.023426979579490817, 'Put Me On', 'Styx'),
#   (0.02339328201859805, 'Forever And A Day', 'Lionel Richie'),
#   (0.02331310927256401, 'Mainstreet', 'Bob Seger')],
#  'Dressed To Kill': [(0.7169636275841871,
#    'Kill The Dog Next Door',
#    'Arrogant Worms'),
#   (0.5967276068301547, "I'll Always Be With You", 'Yoko Ono'),
#   (0.5399237502190906, 'Used To Love Her', "Guns N' Roses"),
#   (0.5287861744994645, "I Didn't Mean To Kill 'Em", 'Insane Clown Posse'),
#   (0.45592457294976985, 'Kill The King', 'Rainbow'),
#   (0.38425088684506986, 'Kill Your Pretty Face', 'W.A.S.P.'),
#   (0.23716299175302813,
#    'Brand New Dance (featuring June Carter)',
#    'Johnny Cash'),
#   (0.2253324019189513, 'Face The Fire', 'Dan Fogelberg'),
#   (0.2203282571922262, 'Kill You', 'Korn'),
#   (0.21720234832033153, 'On The Cross', 'Used'),
#   (0.20384458719191198, 'Bloodline', 'Slayer'),
#   (0.19717029013179124, 'Simon The Bullet Freak', 'Uriah Heep'),
#   (0.19505833302247041, 'Zombie (Rehearsal 1984)', 'Death'),
#   (0.18988865764418544, 'Out Of Here', 'Ramones'),
#   (0.1681166364921165, 'Feel The Fire', 'Overkill'),
#   (0.16724407415868814, 'Thou Shall', 'Young Buck'),
#   (0.16383712757830937, 'Cars And Trains', 'George Michael'),
#   (0.16193099797679078, 'In The Name Of God', 'Ziggy Marley'),
#   (0.15460568873367597, 'Love Song', 'Korn'),
#   (0.1519498582227273, 'Mary', 'Heart'),
#   (0.14977396337370197, 'Losing', 'Marianne Faithfull'),
#   (0.14012186246066133, 'Killing With Kindness', 'Tears For Fears'),
#   (0.13755719455442664, 'Gangsta Gangsta', 'Xzibit'),
#   (0.1277473525729613, 'Cornucopia', 'Black Sabbath'),
#   (0.126896018450753, 'Sureshot', 'Yellowcard'),
#   (0.12269872385135078, 'The Boys Are Back In Town', 'Everclear'),
#   (0.11884324150422058, 'Dream On', 'Depeche Mode'),
#   (0.11318094445911947, "Let's Submerge", 'X-Ray Spex'),
#   (0.11188197899012002, 'I Would', 'One Direction'),
#   (0.10938731339625676, 'Freestyle 2', 'Freestyle'),
#   (0.10887295876521613, 'Searching With My Good Eye Closed', 'Soundgarden'),
#   (0.10744880495328277, 'Love', 'Santana'),
#   (0.10696305604249089, "It's My Life (original Version)", 'Kiss'),
#   (0.10695827494063045, 'Rock Me Baby', 'Etta James'),
#   (0.1031323362794025, 'New Beginnings', 'Faith No More'),
#   (0.10280975038106897, "I'm Gonna Cry (Cry Baby)", 'Wilson Pickett'),
#   (0.10259094891470817, 'A Light That Never Comes', 'Linkin Park'),
#   (0.09746513695496517, 'Love, Hate, Love', 'Alice In Chains'),
#   (0.09745688554530141, 'Damn', 'Leann Rimes'),
#   (0.09732228832657436, 'No No No', 'Deep Purple'),
#   (0.09630102576013147, 'Mother Of Pearl', 'Wishbone Ash'),
#   (0.09501168218759523, 'Let The Good Times Roll', 'Roy Orbison'),
#   (0.0949445511206061, 'Song Inside My Head', 'Arrogant Worms'),
#   (0.09404301984897469, 'A Way With The Blues', 'Beautiful South'),
#   (0.09391630021941164, 'Devil Cried', 'Black Sabbath'),
#   (0.09267166892059729, "Keep On Dancin'", 'Ellie Goulding'),
#   (0.0926224317397105, 'The Fuse', 'Jackson Browne'),
#   (0.09260213249605634, 'Have Mercy On The Criminal', 'Elton John')],
#  'Plastic Concrete': [(0.3776596780676891,
#    'Break Up The Concrete',
#    'Pretenders'),
#   (0.20743745992565707, 'Cornucopia', 'Black Sabbath'),
#   (0.10958934352298257, 'Stone Fire', 'Jimi Hendrix'),
#   (0.10594887770710948, 'Prosthetic Head', 'Green Day'),
#   (0.10436168072841491, 'Mucky Fingers', 'Oasis'),
#   (0.10203123325318732, 'If Six Was Nine', 'Lenny Kravitz'),
#   (0.10027306848873974, 'Everydays', 'Yes'),
#   (0.09433793842930109, 'Still Life', 'Kirsty Maccoll'),
#   (0.0872261465265157, "That's What I Think", 'Cyndi Lauper'),
#   (0.08530037961759905, 'Caffeine', 'Faith No More'),
#   (0.08470968297086484, 'Bullet', 'Misfits'),
#   (0.07976242096872117, "If That's Alright", 'Uncle Tupelo'),
#   (0.07871907473236012, 'Glass Eyes', 'Radiohead'),
#   (0.07780015491285518, "I'm Not Your Baby", 'U2'),
#   (0.07752024994715705, 'Into The Void', 'Kiss'),
#   (0.07722864292200807, 'Keep It Playa', 'Pharrell Williams'),
#   (0.07454329523716181, 'Fall In Love With Me', 'Iggy Pop'),
#   (0.0744367012963519, 'City Of Dreams', 'Widespread Panic'),
#   (0.0725320423981703, 'Highwayman', 'Johnny Cash'),
#   (0.07105250275119411, 'Plastic Bag', 'X-Ray Spex'),
#   (0.06777235432248761,
#    "The Way Life's Meant To Be",
#    'Electric Light Orchestra'),
#   (0.06671655230101763, 'Get Right', 'Pearl Jam'),
#   (0.06641103487365997, 'Eat Your Heart Out', 'Kiss'),
#   (0.06418638793003999, 'I Want Be Man', 'Cheap Trick'),
#   (0.06369971670629199, 'Auf Wiedersehen', 'Cheap Trick'),
#   (0.06203245805440628, "I'm Gonna Cry (Cry Baby)", 'Wilson Pickett'),
#   (0.061515133515060105, 'Section 31', 'Christy Moore'),
#   (0.06004350800469388, 'Heaven Is With You', 'Natalie Cole'),
#   (0.05985170804863002, "I'm New", 'Stevie Wonder'),
#   (0.05967337330060267, 'Oc Life', 'Zebrahead'),
#   (0.059441165185452866, 'I Think I Love You Too Much', 'Dire Straits'),
#   (0.05911075601194213, 'Secret Love', 'Mariah Carey'),
#   (0.05909477162939394, 'Sick, Sick, Sick', 'Queens Of The Stone Age'),
#   (0.058462102579341146, 'In From The Outside', 'Cinderella'),
#   (0.058262046456309814, 'All Screwed Up', 'Ramones'),
#   (0.05741196191425392, 'City Of Dreams', 'Talking Heads'),
#   (0.056928889780994925, 'Baby One More Time', 'Glee'),
#   (0.05638072577212117, 'I Got My Baby', 'Faith Hill'),
#   (0.05607695006097872, "Baby, It's Cold Outside", 'Ella Fitzgerald'),
#   (0.0555672073570973, 'Loved You First', 'One Direction'),
#   (0.05531359378606966, 'Cry Baby', 'Cheap Trick'),
#   (0.055225156244185655, 'Future Love', 'Lady Gaga'),
#   (0.05509258552537881, 'Baby Me Baby', 'Barbra Streisand'),
#   (0.054916585680110395, "What I'm Looking For", 'Christina Aguilera'),
#   (0.05472368026990573, 'She Called Me Baby', 'Glen Campbell'),
#   (0.05453490150517583, 'Save The World', 'George Harrison'),
#   (0.05405280238267892, 'Lost In You', 'Rod Stewart'),
#   (0.05397998219614185, 'Never Named', 'Soundgarden')],
#  'Colorado Christmas': [(0.32759918445583075,
#    'All I Want Is You',
#    'Justin Bieber'),
#   (0.31792361511225853, 'I Saw Three Ships A-Sailing', 'Marianne Faithfull'),
#   (0.31638626173534323, "I'll Be Home For Christmas", 'Vanessa Williams'),
#   (0.29959262019369426, 'All I Want Is You For Christmas', 'Gloria Gaynor'),
#   (0.29087674199206615, 'Oh Christmas Tree', 'Boney M.'),
#   (0.2897394944619266, 'The Christmas Song', 'Arrogant Worms'),
#   (0.28818188420782154, 'Christmas Love', 'Justin Bieber'),
#   (0.28768547634991665, 'All I Want For Christmas Is You', 'Michael Buble'),
#   (0.28686505868866696, "I'll Be Home For Christmas", 'Glee'),
#   (0.2860818896626268, "I'll Be Home For Christmas", 'Barbra Streisand'),
#   (0.2858825731141338, 'Silver Bells', 'Olivia Newton-John'),
#   (0.2710032596713242, "I'll Be Home For Christmas", 'Kenny Chesney'),
#   (0.2698025774705476, "No More Blue Christmas'", 'Natalie Cole'),
#   (0.2661565485455151, 'Please Come Home For Christmas', 'Vonda Shepard'),
#   (0.2658823787248299, 'You Just Gotta Love Christmas', 'Peter Cetera'),
#   (0.2613704230415253, 'Early Christmas Morning', 'Cyndi Lauper'),
#   (0.24432166676329112, 'Merry Christmas', 'Bette Midler'),
#   (0.2424928000236085, 'Silver Bells', 'Garth Brooks'),
#   (0.2355453090586004, 'Silver Bells', 'Bing Crosby'),
#   (0.23212517518916342, 'What Christmas Means To Me', 'Hanson'),
#   (0.2140577471583827, 'Closest Thing To Heaven', 'Tears For Fears'),
#   (0.2129821792181743, 'Blue Christmas', 'Glee'),
#   (0.20546633537032405, 'If Every Day Was Like Christmas', 'Christmas Songs'),
#   (0.20377232668448814, 'Silver Bells', 'Vince Gill'),
#   (0.19931100408389985, "I'll Be Home For Christmas", 'Michael Buble'),
#   (0.19425049485431248, 'Telluride', 'Nitty Gritty Dirt Band'),
#   (0.19248995498688687, 'Merry Christmas, Darling', 'Carpenters'),
#   (0.18871257231676378, 'Meet Me Under The Mistletoe', 'Randy Travis'),
#   (0.18739105636907216, 'Christmas Blues', 'Bob Dylan'),
#   (0.18501716823534295, 'Angel In The Christmas Play', 'Carpenters'),
#   (0.18420761709107394,
#    'A Star Burns Bright (At Christmas)',
#    'Regine Velasquez'),
#   (0.18403990245512944, 'Every Year Every Christmas', 'Luther Vandross'),
#   (0.18179292801503227, "Christmas Time's A-Coming", 'Emmylou Harris'),
#   (0.18166094562894686, "Rockin' Around The Christmas Tree", 'Alabama'),
#   (0.18088704092381314, "Rockin' Round The Christmas Tree", 'Miley Cyrus'),
#   (0.17975828408559, 'Blue Christmas', 'Harry Connick, Jr.'),
#   (0.17791784766805668, 'We Wish You A Merry Christmas', 'Enya'),
#   (0.17607076460083565, 'Christmas Never Comes', 'Cliff Richard'),
#   (0.17376831591093256, 'Child Of Winter', 'Beach Boys'),
#   (0.16720462586405252, 'Under My Tree', "'n Sync"),
#   (0.16399578406322848, 'Christmas In Dixie', 'Alabama'),
#   (0.1620392823815715, 'Merry Christmas, Baby', 'Christina Aguilera'),
#   (0.15091078911777092, 'A Christmas To Remember', 'Amy Grant'),
#   (0.14734316846741274, 'We Wish You A Merry Christmas', 'ABBA'),
#   (0.14674247572065058, 'Snow In California', 'Ariana Grande'),
#   (0.14445514913958304, 'Have Yourself A Merry Little Christmas', 'Bob Dylan'),
#   (0.1440712060779934,
#    'Have Yourself A Merry Little Christmas',
#    'Fifth Harmony'),
#   (0.14053166033554865, 'Follow You Home', 'Ufo')],
#  'Might As Well': [(0.25025290764012126, 'Blue Train', 'Johnny Cash'),
#   (0.24022768892688162, 'Good Time Party', 'Roy Orbison'),
#   (0.1822334358520075, 'Blues Leave Me Alone', 'Eric Clapton'),
#   (0.17904362732257806, 'World Party', 'Waterboys'),
#   (0.17292304960006755, 'Party Lights', 'Natalie Cole'),
#   (0.17127220801336396, 'Ride', 'Kirsty Maccoll'),
#   (0.16819362844814553, 'The Girl For Me', 'Neil Sedaka'),
#   (0.16756808082110128, 'Party Town', 'Eurythmics'),
#   (0.1666476555178013, 'End Of The End', 'Paul McCartney'),
#   (0.1636682379714279, 'My Special Someone', 'Neil Diamond'),
#   (0.16085421481188938, 'Ourselves To Know', 'Warren Zevon'),
#   (0.1604072088413039, 'Ancient Train', 'Travis'),
#   (0.15946243124831125, 'Stop Go', 'Widespread Panic'),
#   (0.15184620290572945, 'Great Pioneer', 'Air Supply'),
#   (0.151656093867073, "I'd Like To Dial Your Number", 'Marianne Faithfull'),
#   (0.14700355356226863, 'Postcard', 'Who'),
#   (0.1411150258979839, 'Ride My See-Saw', 'Moody Blues'),
#   (0.14110257019810254, 'Singing The Blues', 'Frankie Laine'),
#   (0.14048040086800268, 'The Great Divide', 'Tim McGraw'),
#   (0.13458975820099775, "Rock 'n' Roll Pain Train", 'Kid Rock'),
#   (0.1341629753655594, 'If', 'Pink Floyd'),
#   (0.13186828394476136, "Rex's Blues", 'Townes Van Zandt'),
#   (0.1307928734015027, 'Why Must I Cry', 'Peter Tosh'),
#   (0.130721281146485, 'Great King Rat', 'Queen'),
#   (0.1296244855905786, 'North And South Of The River', 'Christy Moore'),
#   (0.12919772075326297, 'Caught Somewhere In Time', 'Iron Maiden'),
#   (0.12879988284047125, 'Rock Me Baby', 'Etta James'),
#   (0.12808587631162105, 'Great Divide', 'Neil Young'),
#   (0.12608564005641235, 'Great In Power', 'Hillsong United'),
#   (0.1259666545924591, 'Tunnel Of Love', 'Dire Straits'),
#   (0.1241187696885521, 'Coffin Car', 'Yoko Ono'),
#   (0.12396115293663987, 'Montana Song', 'Hank Williams Jr.'),
#   (0.1232572484373595, 'People Get Ready', 'Rod Stewart'),
#   (0.1219957445708603, "Let's Take A Ride", 'Justin Timberlake'),
#   (0.12176206822125026, 'Come And Go Blues', 'Allman Brothers Band'),
#   (0.12142996055689875, 'Stay', 'Oingo Boingo'),
#   (0.12142617591338473, 'Let The Good Times Roll', 'Roy Orbison'),
#   (0.12119526694234768, "Cowboy's Sweetheart", 'Leann Rimes'),
#   (0.12070760677948186, 'Clay Pigeons', 'John Prine'),
#   (0.12067920633900175, 'How Long, How Long Blues', 'Nick Cave'),
#   (0.11960871928338045, "Let's Do It For Love", 'Backstreet Boys'),
#   (0.11942671775695755, "Tuesday's Gone", 'Metallica'),
#   (0.11764784133856578, 'Ghettomusick', 'Outkast'),
#   (0.11743637411081795, 'All You Need', 'Divine'),
#   (0.11695226780598175, 'Same Old Blues', 'Freddie King'),
#   (0.11582611824573968, 'Good Like That', 'Kylie Minogue'),
#   (0.11512986879140683, 'Long Time', 'Cake'),
#   (0.11428653255687898, 'Long Time Lie', 'Depeche Mode')],
#  "If God Is Dead (Who's This Living In My Soul)": [(0.29782429813761124,
#    'Living Dead',
#    'King Diamond'),
#   (0.29164975025853995, "God Isn't Dead", 'Extreme'),
#   (0.28175903474275776, 'In The Name Of God', 'Ziggy Marley'),
#   (0.2720821445296572, "Who's That?", 'Squeeze'),
#   (0.24706352871450382, 'Who Will You Run To', 'Heart'),
#   (0.22559053797619957, 'Drive', 'Our Lady Peace'),
#   (0.22424471946490515, '42', 'Coldplay'),
#   (0.2240747011534037, 'Upon My Soul', 'Townes Van Zandt'),
#   (0.21624986726140924, 'How Is Life Going To Be', 'Michael Jackson'),
#   (0.19118539527025813, 'Find Your Self, Discover God', 'Orphaned Land'),
#   (0.18963962741421758, 'Up Above My Head', 'Kirk Franklin'),
#   (0.185618454914094, 'God Compare', 'Horrible Histories'),
#   (0.18085872765296857, 'Children', 'Justin Bieber'),
#   (0.1775557869550763, 'After Forever', 'Black Sabbath'),
#   (0.17499513753281606, 'New Frontier', 'Iron Maiden'),
#   (0.17474413263460203, 'Jesus Is A Soul Man', 'Loretta Lynn'),
#   (0.1724594845334072, 'Kite', 'U2'),
#   (0.1679822445869462, 'Starting Over', 'Korn'),
#   (0.16586080182196636, 'Sold My Soul', 'Nazareth'),
#   (0.1618238348311536, 'God Must Have Spent', "'n Sync"),
#   (0.16139703317781356, '10,000 Reasons', 'Matt Redman'),
#   (0.16128779018992476, 'Dead Heaven', 'Gary Numan'),
#   (0.16067965420970876, 'A Living Prayer', 'Alison Krauss'),
#   (0.15605112289629156, 'I Know Very Well How I Got My Name', 'Morrissey'),
#   (0.15492377770743868, 'Dead End', 'Jason Mraz'),
#   (0.1525237386432932, 'Open Your Soul To Me', 'Yoko Ono'),
#   (0.1352573509602125, 'D.O.A.', 'Van Halen'),
#   (0.13364012047954968, 'This I Love', "Guns N' Roses"),
#   (0.13010429202533477, 'Take Heart', 'Donna Summer'),
#   (0.1296051834754008, 'Shout Your Fame', 'Hillsong'),
#   (0.12918522476596533, 'Save The Last Dance For Me', 'Michael Buble'),
#   (0.12787282346378331, 'Dangerous Game', 'Gloria Estefan'),
#   (0.12515172202739475, 'One (Rare)', 'Metallica'),
#   (0.12474892809224959, 'Ask Me', 'Amy Grant'),
#   (0.12392354587451616, 'Missing You', 'Amy Grant'),
#   (0.1236473669645932, 'Help Me Make It Through The Night', 'Willie Nelson'),
#   (0.12287456002813707, 'Soul Radio', 'Fastball'),
#   (0.1228315638765196, 'Dead Man Walking', 'David Bowie'),
#   (0.12234841835398645, 'Perfect Little Heart', 'Uriah Heep'),
#   (0.12223052168876761, 'Soul Rebel', 'UB40'),
#   (0.12213806361935459, 'Curtains', 'Lil Wayne'),
#   (0.12050895001972162, 'What If God Smoked Cannabis?', 'Bob Rivers'),
#   (0.12002967599852601, 'Zombie (Rehearsal 1984)', 'Death'),
#   (0.11895984693420637, 'In My First Mind', 'Steve Miller Band'),
#   (0.11822917908374823, 'Search And Destroy', 'Iggy Pop'),
#   (0.11806324005065363, "I'd Rather Be High", 'David Bowie'),
#   (0.11790762091427925, "Baby's House", 'Steve Miller Band'),
#   (0.11720240694266898, 'Someone', 'James Taylor')],
#  'The Bed': [(0.22259279002898888, 'Bed Of Roses', 'Bon Jovi'),
#   (0.1778759925848402, 'For The Good Times', 'Willie Nelson'),
#   (0.17492291011050345, 'MY COLD, COLD HEART IS MELTED NOW', 'Hank Williams'),
#   (0.1731109659776186, 'For The Good Times', 'Loretta Lynn'),
#   (0.1669929072054018, 'One More Night', 'Fleetwood Mac'),
#   (0.1642653112464154, 'Enter Sandman', 'Metallica'),
#   (0.14609640296093737, 'Kiss Me', 'Demi Lovato'),
#   (0.14259013898800685, 'Dead End', 'Jason Mraz'),
#   (0.139267844727478, 'Separator', 'Radiohead'),
#   (0.13435918866722513, 'Staring At The Stars', 'Passenger'),
#   (0.13373702841690896, 'On The Other Hand', 'Randy Travis'),
#   (0.13111642313923358, 'I Still Remember', 'Gary Numan'),
#   (0.13045053937620207, 'Vodevil', 'Marilyn Manson'),
#   (0.1272116130336952, "I'll Kiss You", 'Cyndi Lauper'),
#   (0.12459464248700991, 'A Head Full Of Dreams', 'Coldplay'),
#   (0.12264716206069741, 'Just Another Day', 'Natalie Imbruglia'),
#   (0.12166606592908567, 'It Must Have Been Love', 'Oasis'),
#   (0.1183379653115819, "There's A Tear In My Beer", 'Hank Williams'),
#   (0.1183150628137497, 'Tears On My Pillow', 'Grease'),
#   (0.11803836529969422, 'Kiss And Make Up', 'Eddie Cochran'),
#   (0.11671196023596966, 'The Strangest Thing', 'George Michael'),
#   (0.11623121714369371, 'Good Night', 'Overkill'),
#   (0.11613064558536955, 'Wrap Your Arms Around Me', 'Engelbert Humperdinck'),
#   (0.1154698339184749, 'Lay It Down', 'Aerosmith'),
#   (0.11513456993608857, 'Angels Of The Silences', 'Counting Crows'),
#   (0.1145261124606221, 'In The Warm Room', 'Kate Bush'),
#   (0.11316493283183682, 'My Hearts With You', 'Air Supply'),
#   (0.11310761345138565, 'Affair On 8Th Avenue', 'Gordon Lightfoot'),
#   (0.11142182554902351, 'Troy', 'Josh Groban'),
#   (0.11101405811380496, 'One Night', 'Etta James'),
#   (0.11093569689073352, 'Walk Hand In Hand', 'Engelbert Humperdinck'),
#   (0.10978713562460442, 'Hold On', 'Pearl Jam'),
#   (0.10941128325516916, 'Hand On Heart', 'Olly Murs'),
#   (0.10915048469886586, 'John Cockers', 'John Mellencamp'),
#   (0.10900471527965559, 'Blue Skies', 'Tom Waits'),
#   (0.10762175917367721, 'Sleeping With A Friend', 'Squeeze'),
#   (0.107401596810616, 'Silent Night', 'Mariah Carey'),
#   (0.10726439059989205, 'Just Out Of Reach', 'Perry Como'),
#   (0.10663495724700486, 'In My Dreams', 'Pat Benatar'),
#   (0.10622946568187822, 'In Another Land', 'Rolling Stones'),
#   (0.10603321626070696, 'Mistress Dread', 'Metallica'),
#   (0.10595103428515706, 'Fire', 'Bruce Springsteen'),
#   (0.10547102814558396, 'The Flame', 'Cheap Trick'),
#   (0.10519351599210373, 'I Wanna Get Back With You', 'Tori Amos'),
#   (0.10459020645574656, 'Our House', 'Talking Heads'),
#   (0.10414963228813506, 'Blackout Blues', 'Widespread Panic'),
#   (0.1032445180720418, 'Star Carol', 'Paul Simon'),
#   (0.10253720747839767, 'Somewhere', 'Phil Collins')],
#  'Take A Load Off': [(0.20761785533976201, 'Glory Road', 'Neil Diamond'),
#   (0.19890809091649073, 'The Weight', 'Allman Brothers Band'),
#   (0.1697267683210814, 'For The Record', 'Mariah Carey'),
#   (0.1614623903883917, 'Just For The Record', 'Marillion'),
#   (0.1495465312844544, 'Brothers Of The Road', 'Allman Brothers Band'),
#   (0.14122504376521886, 'No Sign Of It', 'Natalie Grant'),
#   (0.12802267702091882, 'Ballad For A Friend', 'Bob Dylan'),
#   (0.11780040662844586, 'Free', 'Kirk Franklin'),
#   (0.11775054559906885, 'Freedom Now', 'Tracy Chapman'),
#   (0.11476675219257955, 'Raised On You', 'Heart'),
#   (0.11391047413900397, 'Look Of Today', 'Enigma'),
#   (0.11327254411933367, 'I Know You Better Than You Think', 'Air Supply'),
#   (0.10501590285792863, 'Hitchhiker', 'Neil Young'),
#   (0.09084296389870224, 'Solve My Mystery', 'Oasis'),
#   (0.08904857642148704, 'Nobody But You', 'Lou Reed'),
#   (0.08897902468181094, "Everything I'll Ever Own", 'Reba Mcentire'),
#   (0.08471575293472178, "Keepin' The Summer Alive", 'Beach Boys'),
#   (0.08467003011357367, "Fuckin' Up", 'Neil Young'),
#   (0.0844922078084643, "Chastity's Song (Band Of Thieves)", 'Cher'),
#   (0.08442462027119302, 'Miss Independent', 'Ne-Yo'),
#   (0.08189150147493036, 'Love And Laundry', 'Point Of Grace'),
#   (0.08088293883169285, 'Whatever', 'Oasis'),
#   (0.08003075776007372, 'I Want To Be Around', 'Arlo Guthrie'),
#   (0.08001236571349893, 'The Mark 2:14', 'Overkill'),
#   (0.07912546917885091, "(We're Not) The Jet Set", 'John Prine'),
#   (0.0787880325789414, 'Telluride', 'Nitty Gritty Dirt Band'),
#   (0.07835560998940413, 'Big Eyes', 'Lana Del Rey'),
#   (0.07743267319351373, 'People Are The Same Everywhere', 'Morrissey'),
#   (0.07729742171890194, 'Cheap Shot', 'John Mellencamp'),
#   (0.07591497053518999, "Why Can't We", 'Leann Rimes'),
#   (0.07464392118877582, 'Running Free - Live', 'Iron Maiden'),
#   (0.07426044920340351, 'Opiated', 'Tragically Hip'),
#   (0.07323933178988773, "Wild 'n Free", 'Ian Hunter'),
#   (0.0732220519475284, 'Everything For Christmas', 'The Temptations'),
#   (0.07211386064259541, 'Beady Eyed Buzzard', 'Perry Como'),
#   (0.07068522314880775, 'I Knew You When', 'Linda Ronstadt'),
#   (0.0696847388245189, 'Looking In The Mirror', 'David Allan Coe'),
#   (0.06963923955671879, 'Diamonds On The Soles Of Her Shoes', 'Paul Simon'),
#   (0.06962370328619236, 'Stone Fire', 'Jimi Hendrix'),
#   (0.06955944779313832, 'Where I End And You Begin', 'Radiohead'),
#   (0.06939854121698452, "It's Alright", 'Ray Charles'),
#   (0.06905550563638704, 'Island In The Sun', 'Harry Belafonte'),
#   (0.06898886717693035, 'Tonight Will Be Alright', 'Lionel Richie'),
#   (0.06870682399194915, 'Winner Take All', 'Styx'),
#   (0.0686804716632002, 'Superstition', 'Lenny Kravitz'),
#   (0.06828585959666975, 'Jesus Is Love (Long Version)', 'Lionel Richie'),
#   (0.06807805492133746, 'Steal Your Heart', 'Gloria Estefan'),
#   (0.06800725312311351, 'Velcro Fly', 'ZZ Top')],
#  "I've Got A Pocketful Of Dreams": [(0.18972293514165658,
#    'I Feel Lucky',
#    'Pat Benatar'),
#   (0.17679258752552757, 'Lucky Me', 'Chris Brown'),
#   (0.17446750329424496, 'One Life', 'Kenny Rogers'),
#   (0.16592746066515218, 'The Lucky One', 'Vertical Horizon'),
#   (0.16017001822668164, 'Dreams Come True', 'Westlife'),
#   (0.15482447246212006, 'Could It Be You?', "'n Sync"),
#   (0.14598110139809908, 'Here I Go Again', 'Whitesnake'),
#   (0.14177917424398723, 'Constant As The Stars Above', 'Barbie'),
#   (0.14048719363013992, 'A Different Point Of View', 'Pet Shop Boys'),
#   (0.13131623627099825, 'Jenny Rebecca', 'Neil Diamond'),
#   (0.13072138565916788, 'Lucky In Love', 'Kris Kristofferson'),
#   (0.13045161906649186, 'Lucky Man', 'Electric Light Orchestra'),
#   (0.13037034066469697, "I've Got The Sun In The Morning", 'Judy Garland'),
#   (0.12940868815034479, 'Working At Perfekt', 'Rush'),
#   (0.1292350892541202, 'All The Way With You', 'John Prine'),
#   (0.12840872185727756, "I'll Be Lucky Someday", 'Glen Campbell'),
#   (0.12646177425391558, 'Come On Nature', 'Proclaimers'),
#   (0.12148905202148359, 'A Head Full Of Dreams', 'Coldplay'),
#   (0.12112215996056414, 'Propinquity', 'Nitty Gritty Dirt Band'),
#   (0.11899231905163062, 'Newborn', 'Depeche Mode'),
#   (0.11826403403096775, 'Closer', 'Westlife'),
#   (0.11796712619680105, 'Through', 'George Michael'),
#   (0.114464581333421, 'Back On Top', 'Van Morrison'),
#   (0.11431297747988875, 'N. S. U.', 'Eric Clapton'),
#   (0.114118747316757, 'Overnight Sensation', 'Tina Turner'),
#   (0.11269382159230962, 'Glorious', 'Natalie Imbruglia'),
#   (0.11201725525203811, 'One In The Sun', 'Lynyrd Skynyrd'),
#   (0.11101421020432885, 'Ship Of Fools', 'Alphaville'),
#   (0.11060543491565698, 'She Got Her Own', 'Ne-Yo'),
#   (0.11016307104370175, 'Couple More Years', 'Waylon Jennings'),
#   (0.10936402157368447, 'Give A Little Love', 'Tom Jones'),
#   (0.10899070735888018, 'Had To Fall In Love', 'Moody Blues'),
#   (0.10623219763815993, 'Age Of Consent', 'New Order'),
#   (0.1046239599613118, "Time Is Runnin'", 'Cheap Trick'),
#   (0.10434778386320563, 'From Luxury To Heartache', 'Culture Club'),
#   (0.10366821274361315, 'Tell Me A Story', 'Iggy Pop'),
#   (0.10285723533226851, 'One Together', 'Fleetwood Mac'),
#   (0.10220691154601624, 'Hey Girl', 'John Legend'),
#   (0.1018993752364338, 'Bulimic', 'Used'),
#   (0.10174124549477356,
#    'That Lucky Old Sun Just Rolls Around Heaven',
#    'Ray Charles'),
#   (0.10122180996395422, 'Scent Of A Woman', 'Xzibit'),
#   (0.10004693388214307, 'Style It Takes', 'Lou Reed'),
#   (0.09997645534771557, 'Homecoming', 'Kanye West'),
#   (0.0997997301790767, 'I Want You To Know', 'Planetshakers'),
#   (0.0987517394279454, 'Right There', 'Ariana Grande'),
#   (0.09790797885241193, 'Out Of Love', 'John Prine'),
#   (0.09649684841635013, 'Qaundary', 'Chaka Khan'),
#   (0.09627524292721154, 'Whatever It Is', 'Zac Brown Band')],
#  'John Cockers': [(0.22853633919860666, 'Hard Times', 'Arlo Guthrie'),
#   (0.22142094586368855, "I've Got The Sun In The Morning", 'Judy Garland'),
#   (0.21826477695618696, "Keep On Keepin' On", 'Allman Brothers Band'),
#   (0.2182558868919036, 'You And Me', 'Justin Bieber'),
#   (0.21109489860993252, 'Brother Where You Bound', 'Supertramp'),
#   (0.19857001921354092, "Blaze's Blues", 'Townes Van Zandt'),
#   (0.19706456104328934, "I Don't Care Anymore", 'Phil Collins'),
#   (0.19301756148711627, 'I Will Be There', 'Britney Spears'),
#   (0.19266672888193676, 'Let Go', 'Ne-Yo'),
#   (0.1900538300285906, 'If Six Was Nine', 'Lenny Kravitz'),
#   (0.1874821187272497, "The Future Ain't What It Used To Be", 'Meat Loaf'),
#   (0.1867645700073646, 'One In The Sun', 'Lynyrd Skynyrd'),
#   (0.18640732938606977, 'She Got Her Own', 'Ne-Yo'),
#   (0.18591221475886083, 'Ironbound', 'Overkill'),
#   (0.1804163005569406, 'Abilene', 'Yes'),
#   (0.1788233423899214, 'I Want To Be Loved', 'Bon Jovi'),
#   (0.17639699769275502,
#    'Brand New Dance (featuring June Carter)',
#    'Johnny Cash'),
#   (0.17637729070214708, 'Girls Love Beyonce', 'Drake'),
#   (0.17609084931083627, 'Secret Agent', 'Air Supply'),
#   (0.1735427820747893, 'To Love Somebody', 'Michael Bolton'),
#   (0.17325841494547398, 'Scarecrow People', 'XTC'),
#   (0.1726960567998252, 'Perfect Little Heart', 'Uriah Heep'),
#   (0.17137191049023862, "It Ain't Easy When You Fall", 'Ian Hunter'),
#   (0.1693990296756988, 'We Got All Night', 'America'),
#   (0.1679863077566296, "Don't Speak Of Love", 'Dusty Springfield'),
#   (0.16654813035276955, "Girls It Ain't Easy", 'Dusty Springfield'),
#   (0.16612625295294864, 'Hard Headed Woman', 'Cat Stevens'),
#   (0.1660159578932268, 'My Hearts With You', 'Air Supply'),
#   (0.16576369273320668, 'Bad Boy', 'Eric Clapton'),
#   (0.16364456839239266, 'Just Friends', 'Vanessa Williams'),
#   (0.16226082925506202, "Don't Think Twice It's Alright", 'John Martyn'),
#   (0.16165669948670716, 'Gemini Song', 'Waylon Jennings'),
#   (0.1613028900272998, "It's All Over Now", 'Rod Stewart'),
#   (0.16098303571081377, 'In the Morning', 'J Cole'),
#   (0.16094058295811273, 'Try Too Hard', 'P!nk'),
#   (0.16079933785107647, 'Standing In The Shadows', 'Hank Williams Jr.'),
#   (0.1606542493516315, "When I'm With You", 'Kyla'),
#   (0.1596117844679722, 'Lonesome Rodeo Cowboy', 'George Strait'),
#   (0.15943981055395548, 'Two More Lonely People', 'Miley Cyrus'),
#   (0.15796901688147105, 'Rich Kid Blues', 'Marianne Faithfull'),
#   (0.1579198741412828, 'Million Miles', 'Heart'),
#   (0.15694545040951097, 'Too Much', 'Drake'),
#   (0.15676196429285214, 'Eye In The Sky', 'Noa'),
#   (0.15437316137695672, "Ain't Nothing Like The Real Thing", 'Diana Ross'),
#   (0.15415197126551625, "Ninety-Nine And A Half (Won't Do)", 'Wilson Pickett'),
#   (0.15394534830167644, "Everything Ain't Right", 'George Jones'),
#   (0.15394396912617722, 'Best Friend', 'Adam Sandler'),
#   (0.1520163931761695, 'We The People', 'Air Supply')],
#  "I'se The B'y": [(0.18114351731463252, 'Come Back Liza', 'Harry Belafonte'),
#   (0.10210809695727727, 'Lay Down Sally', 'Eric Clapton'),
#   (0.0978902234482256, 'The Fishing Song', 'Arrogant Worms'),
#   (0.09627732650305408, 'Sally Simpson', 'Who'),
#   (0.09284355181385096, 'Foggy Notion', 'Lou Reed'),
#   (0.07803139617713457, 'I Will Be There', 'Britney Spears'),
#   (0.07089108285151256, 'Oliver, Oliver!', 'Oliver'),
#   (0.06880245103800352, 'In Our Small Way', 'Michael Jackson'),
#   (0.067087432750955, 'You And Me Together', 'Miley Cyrus'),
#   (0.06523629099152443, 'Good Like That', 'Kylie Minogue'),
#   (0.06450486529380758, 'Count On Me', 'Whitney Houston'),
#   (0.0643622876027811, 'Lining Track', 'John Denver'),
#   (0.06399052361309732, 'Give You Back', 'Vertical Horizon'),
#   (0.06358152150358422, "Who's That Man?", 'Xscape'),
#   (0.06347715813722414, 'Just Across The Bridge Of Gold', 'Hank Snow'),
#   (0.0632031306799717, 'Question', "Old 97's"),
#   (0.06284375791816697, 'Promise My Prayers', 'Point Of Grace'),
#   (0.06269760970854758, 'Birthday Cake', 'Rihanna'),
#   (0.06263618166016283, "Sinner's Prayer", 'Lady Gaga'),
#   (0.06209132396416296, 'Fish And Whistle', 'John Prine'),
#   (0.061150739192044945, 'Real Good Man', 'Tim McGraw'),
#   (0.061009231232741205, 'Hurry Come On Up', 'UB40'),
#   (0.0604534391259047, 'We Could Have Been', 'Bryan White'),
#   (0.05986495104940689, 'Last Mango In Paris', 'Jimmy Buffett'),
#   (0.059623759109806856, 'Remember Me', 'Lucky Dube'),
#   (0.059543630038369724, 'Bad Boy', 'Eric Clapton'),
#   (0.05835554174705797, 'Going To Paris', 'Waterboys'),
#   (0.05832633488141687, 'Black Sails In The Sunset', 'Elvis Costello'),
#   (0.058127375217355254, 'Ball And Chain', 'Poison'),
#   (0.057903344760189324, 'Only A Fool Would Say That', 'Steely Dan'),
#   (0.05722201421888502, '(all I Can Do Is) Dream You', 'Roy Orbison'),
#   (0.05696204235391121, 'Perfect World', 'Peter Cetera'),
#   (0.05656660489912325, 'Devil Woman', 'Poison'),
#   (0.05652192847510667, 'Tuna', 'Hooverphonic'),
#   (0.05516691668517638, 'Postcard', 'Who'),
#   (0.055002191606273766, 'Have You Ever', 'Westlife'),
#   (0.05341336893870355, "You're No Good", 'Wilson Phillips'),
#   (0.053081581151913984, 'Connection', 'Arlo Guthrie'),
#   (0.0530443862245909, 'Home', 'Mary Black'),
#   (0.05300763922104343, 'Go Tell It On The Mountain', 'Ray Boltz'),
#   (0.053000313879259825, 'Dirty Laundry', 'Don Henley'),
#   (0.05257311805814512, 'Kiss Your Freedom Goodbye', 'Lynyrd Skynyrd'),
#   (0.05249224366367456, 'Deeper', 'Xzibit'),
#   (0.052376949541378934, 'Molina', 'Creedence Clearwater Revival'),
#   (0.05224865596224426, 'Insignificant', 'Counting Crows'),
#   (0.05187401590606214, 'I Wanna Be Your Man (Forever)', 'Keith Urban'),
#   (0.05150760033817939, 'Bell Bottom Blues', 'Eric Clapton'),
#   (0.05124833788947873, 'Let The Good Times Roll', 'Yngwie Malmsteen')],
#  "Childhood's End": [(0.18172209625792812, 'The Lady Lies', 'Genesis'),
#   (0.17804467820182449, 'Death Is Not The End', 'Kylie Minogue'),
#   (0.15891761933229837, 'Blind Love', 'Freestyle'),
#   (0.15579967598892425, 'Book Of Love', 'Air Supply'),
#   (0.1538063031676494, 'A Time For Letting Go', 'Michael Bolton'),
#   (0.15230671896460274, 'Happy? - Intwine', 'HIM'),
#   (0.15200104901036948, 'Ordinary Pain', 'Stevie Wonder'),
#   (0.15179160349200563, "Tomorrow's Gone", 'Yngwie Malmsteen'),
#   (0.1501002608121999, 'I Might Get Over You', 'Kenny Chesney'),
#   (0.14509368639273162, 'Love Of My Life', 'Carly Simon'),
#   (0.1435304213532214, 'A Handful Of Pain', 'Helloween'),
#   (0.1431208816723739, 'Falling Out Of Love With Me', 'Dolly Parton'),
#   (0.14258773069822359, 'Have A Heart', 'Celine Dion'),
#   (0.13944033049900068, 'Bad Moon Rising', 'Bruce Springsteen'),
#   (0.139186925522484, 'One Last Time', 'One Direction'),
#   (0.13789508091963304, 'Just Another Day', 'Natalie Imbruglia'),
#   (0.13736414912873285, 'Love', 'Santana'),
#   (0.1370500442981595, 'For Your Love', 'Stevie Wonder'),
#   (0.13545385973323557, 'Smile Again', 'Usher'),
#   (0.13103073941924714, 'Count On Me', 'Whitney Houston'),
#   (0.13075883055328677, 'Road To Acceptance', 'Green Day'),
#   (0.13038246840667803, 'The Past', 'Korn'),
#   (0.13014006826077995, 'I Love You', 'Celine Dion'),
#   (0.12973835020588004, 'Just A Name', 'Cher'),
#   (0.1297266821658999, 'Anywhere For You', 'Backstreet Boys'),
#   (0.1291130530777627, 'More To Life', 'Cliff Richard'),
#   (0.12906010869714435,
#    'I Wish That I Could Hurt That Way Again',
#    'Kenny Rogers'),
#   (0.1268477335146053, 'The Wolves', 'Ellie Goulding'),
#   (0.1263973118164322, 'Good Riddance', 'Green Day'),
#   (0.12612176951264417, "Rock 'n' Roll Pain Train", 'Kid Rock'),
#   (0.12605741391934477, 'A Different Corner', 'Wham!'),
#   (0.12560471685187247, 'Coins In A Fountain', 'Passenger'),
#   (0.12529796883447766, 'A Different Corner', 'George Michael'),
#   (0.12517828467452663, 'One Man, One Woman', 'ABBA'),
#   (0.1250914735710104, 'Love Will Make It Right', 'Diana Ross'),
#   (0.12489937179813407, "It's You", 'Bob Seger'),
#   (0.12456645153544732, 'You Never Let Go', 'Matt Redman'),
#   (0.12347886907829474, "Love Don't Love Nobody", 'Eric Clapton'),
#   (0.1231237560785283, 'Just Like A Woman', 'John Waite'),
#   (0.12304183325709837, 'I Wanna Get Back With You', 'Tori Amos'),
#   (0.1230171589448908, 'Why Must I Cry', 'Peter Tosh'),
#   (0.12236918048918995, 'Our Love', 'Natalie Cole'),
#   (0.12205956495759888, 'Hide And Seek', 'Howard Jones'),
#   (0.12189452299357798, 'My Centurion', 'Gary Numan'),
#   (0.12074114291757944, 'I Love You', 'Faith Hill'),
#   (0.12001244191393773, "Don't Fear The Reaper", 'Beautiful South'),
#   (0.11992886972658971, 'Dance With My Father', 'Luther Vandross'),
#   (0.11909059805924883, 'Man That You Fear', 'Marilyn Manson')],
#  "It Just Won't Quit": [(0.2856783006063371, 'Maybe Today', 'Bob Seger'),
#   (0.22182602484454514, 'Cross The Line', 'Yngwie Malmsteen'),
#   (0.21948891105522567, 'Hey Girl', 'John Legend'),
#   (0.21909406471858905,
#    'Headfirst Slide Into Cooperstown On A Bad Bet',
#    'Fall Out Boy'),
#   (0.2176985927289887, 'Used To Love Him', 'Fiona Apple'),
#   (0.21516634144424496, 'Permanent December', 'Miley Cyrus'),
#   (0.20520581212479594, 'I Love You', 'Celine Dion'),
#   (0.20430372446522277, 'Universe', 'Savage Garden'),
#   (0.20040256719050975, "3 Doors Down - When I'm Gone", 'Various Artists'),
#   (0.19948382649503552, "Maybe I'm Right", 'Linda Ronstadt'),
#   (0.19550888722607898, 'Halah', 'Mazzy Star'),
#   (0.19385288826640754, 'Love Drunk', 'Little Mix'),
#   (0.1937227664439444, 'How Does It Feel To Be Free', 'Reba Mcentire'),
#   (0.19253545774347927, 'Almost', 'Tracy Chapman'),
#   (0.19250239903839536, 'Part Of Me', 'Tool'),
#   (0.1921604989064157, 'If You Really Love Me', 'Stevie Wonder'),
#   (0.1920684111481617, 'Lonesome Rodeo Cowboy', 'George Strait'),
#   (0.19144572654960587, 'Heart To Heart', 'Kyla'),
#   (0.19102274009479872, "I Don't Wanna Know", 'Puff Daddy'),
#   (0.1899432968295342, "You Won't See Me", 'Reo Speedwagon'),
#   (0.1872633311538496, 'After Tonight', 'Reo Speedwagon'),
#   (0.18665720420129242, 'I Love You', 'Faith Hill'),
#   (0.1863872286299251, "Don't Want To Fight Anymore", 'Howard Jones'),
#   (0.18562708388713586, 'Not Drunk Enough', 'Adele'),
#   (0.182828485568339, "This Time I Know It's For Real", 'Donna Summer'),
#   (0.18008890788602352, 'My Hearts With You', 'Air Supply'),
#   (0.1771577725654839, 'Something', 'Drake'),
#   (0.17637928126079572, 'Equality', 'Howard Jones'),
#   (0.17621827311576682, "It's All Over Now", 'Rod Stewart'),
#   (0.17603485148911144, 'Does Your Mother Know', 'Gordon Lightfoot'),
#   (0.17508371579105908, 'Something Coming Over', 'O.A.R.'),
#   (0.17495250397904666, 'Get Down Like That', 'Ne-Yo'),
#   (0.1734942037909295, 'I Give Up', 'Heart'),
#   (0.17193706033755068, 'Heroin', 'Lou Reed'),
#   (0.1716864905085497, 'Maybe Tomorrow', 'Westlife'),
#   (0.17139487587539104, 'Maybe Baby', 'Nitty Gritty Dirt Band'),
#   (0.16975221176715746, 'For Once In My Life', 'Stevie Wonder'),
#   (0.1691346085178188, 'Let Forever Be', 'Oasis'),
#   (0.16877648755023392, "I Really Don't Want To Know", 'Dolly Parton'),
#   (0.16834775067468197, "Don't", 'Elvis Presley'),
#   (0.16747004545435015, 'The Life Machine', 'Gary Numan'),
#   (0.16723469164954874, 'How Does It Feel', 'Toto'),
#   (0.1658134059857774, 'In My Dreams', 'Pat Benatar'),
#   (0.16445727683299913, 'Just Like A Woman', 'John Waite'),
#   (0.16425927062982565, "It's You", 'Bob Seger'),
#   (0.16416056889804026, 'How Will I Know', 'Lucky Dube'),
#   (0.16393006519959524, 'Raised On You', 'Heart'),
#   (0.16374481684136563, 'Come In With The Rain', 'Demi Lovato')],
#  'Hand On My Heart': [(0.5277831576447287, 'Hand On Heart', 'Olly Murs'),
#   (0.41509070427637845, "Don't Close Your Heart", 'HIM'),
#   (0.37197298460042005, 'Anything Is Possible', 'Modern Talking'),
#   (0.3589036242852462, "Please Don't Let It Go", 'HIM'),
#   (0.3301983821715899, 'Let Me Let Go', 'Faith Hill'),
#   (0.32940117939894653, 'Talk To Me', 'Quarterflash'),
#   (0.3166153057030493, "I'd Have You Anytime", 'George Harrison'),
#   (0.30199858869014873, 'Walk Hand In Hand', 'Engelbert Humperdinck'),
#   (0.3017938832258135, 'When I Close My Eyes', 'Kenny Chesney'),
#   (0.2993760651932307, 'Breaking Your Own Heart', 'Kelly Clarkson'),
#   (0.2970408088141158, 'On The Other Hand', 'Randy Travis'),
#   (0.29305286170137845, 'Let Go', 'Ne-Yo'),
#   (0.28891518621212825,
#    "Don't Talk (Put Your Head On My Shoulder)",
#    'Linda Ronstadt'),
#   (0.2884008637979277, "Don't Let The Stars Get In Your Eyes", 'George Jones'),
#   (0.2845884940427414, '(all I Can Do Is) Dream You', 'Roy Orbison'),
#   (0.28307242169961344, 'Have A Heart', 'Celine Dion'),
#   (0.27892485731915373, 'I Will Be There', 'Britney Spears'),
#   (0.2787091052026373, 'My Heart Will Go On', 'Neil Diamond'),
#   (0.27685663976223096, "I Don't Wanna Know", 'Puff Daddy'),
#   (0.2699389709864965, "I Don't Have To Sleep To Dream", 'Cher'),
#   (0.2650935869191184, 'Let Me Love It Out Of You', 'Tim McGraw'),
#   (0.2624810468261266, "Don't Let It Get You Down", 'America'),
#   (0.2617007625617731, "Don't Let Me Down", 'Hollies'),
#   (0.25960524411956, 'You Never Let Go', 'Matt Redman'),
#   (0.25470334250872956, "Don't", 'Elvis Presley'),
#   (0.25379820947691667, 'Let Me Down Easy', 'Isley Brothers'),
#   (0.252955383812959, 'Universe', 'Savage Garden'),
#   (0.2484350285418927, 'Lonely', 'Tom Waits'),
#   (0.24005488180873963, 'Two More Lonely People', 'Miley Cyrus'),
#   (0.23935776879010873, "It's Alright", 'Chicago'),
#   (0.2380894817663619, "This Guy's In Love With You", 'Frankie Valli'),
#   (0.23531989596481037, 'Dream Of Me', 'Backstreet Boys'),
#   (0.23524248964583613, 'Part Time Lover', 'Modern Talking'),
#   (0.2350403332491704, 'All I Have', 'Modern Talking'),
#   (0.23466058409716556, 'Let Yourself Go', 'Alan Parsons Project'),
#   (0.2339651018842887, 'Shape Of My Heart', 'Backstreet Boys'),
#   (0.2311193363919171, 'Heart Like A Wheel', 'Black Sabbath'),
#   (0.23108198397216123, 'Last Chance', 'Kyla'),
#   (0.23072426275013758, 'Take Me', 'Noa'),
#   (0.22849972923825304, 'Lonely', 'Eddie Cochran'),
#   (0.22799885709267761, 'Deadly Sting Suite', 'Scorpions'),
#   (0.2261249194851098,
#    'Please, Please, Please, Let Me Get What I Want',
#    'Smiths'),
#   (0.22525164709311685, 'Close Enough To Love', 'Conway Twitty'),
#   (0.22487596096466406, 'Permanent December', 'Miley Cyrus'),
#   (0.22402092871583215, 'Please, Please, Please', 'Who'),
#   (0.22341566533467852, 'Never Be Lonely', 'America'),
#   (0.22303674108217236, 'Close But No Cigar', 'Weird Al Yankovic'),
#   (0.22230220523455033, 'Always On Time', 'Kyla')],
#  'Big Boots': [(0.17273262242407755, 'The Gaelic Song', 'Arrogant Worms'),
#   (0.1321579427589358, 'Big Eyes', 'Lana Del Rey'),
#   (0.10279406436840488, 'Big Boss Man', 'Elvis Presley'),
#   (0.09772929614650334, 'Big World', 'Wang Chung'),
#   (0.09627681780505813, "Don't Cry Daddy", 'Elvis Presley'),
#   (0.09016101549378565, 'Dancing With The Big Boys', 'Iggy Pop'),
#   (0.08568115223809904, 'Big As I Can Dream', 'Roy Orbison'),
#   (0.08135212194741512, 'In The Dark', 'Violent Femmes'),
#   (0.08114798730309407, 'Big Fat Money', 'Van Halen'),
#   (0.07415424479485806, 'Big Brown Eyes', "Old 97's"),
#   (0.07193783964701944, 'Guns In The Ghetto', 'UB40'),
#   (0.06904273600383004, 'Daddy, Daddy, Daddy', 'Frank Zappa'),
#   (0.06410344838513996, "Hey Daddy (Daddy's Home)", 'Usher'),
#   (0.061786569744256926, 'How Big Is God', 'Hank Snow'),
#   (0.06027295571823449, "Modern Times Rock'n'Roll", 'Queen'),
#   (0.05780911121154972, 'Hey', 'Hanson'),
#   (0.05737784364834055, 'Little Girl', 'Reba Mcentire'),
#   (0.05624130606457378, 'Big Road', 'Bonnie Raitt'),
#   (0.05262815026410953, "Rock 'n Roll Is Music Now", 'James Taylor'),
#   (0.05173919086932951, 'Remember Me', 'Lucky Dube'),
#   (0.05129311333550085, 'My Big Mouth', 'Oasis'),
#   (0.05094215483720626, 'Spaghetti Western', 'Primus'),
#   (0.05085265754326773, 'Fool To Cry', 'Rolling Stones'),
#   (0.04991105638249411, 'Big Poppa', 'Notorious B.I.G.'),
#   (0.049717179595358416, 'Defying Gravity', 'Jimmy Buffett'),
# ...
#   (0.15069217780036295, 'Devil Woman', 'Poison'),
#   (0.1498999243964063, "Young Girl's Heart", 'Steve Miller Band'),
#   (0.14810968645005704, 'In The Deathcar', 'Iggy Pop'),
#   (0.14790309778675084, 'Seven Mile Bridge', 'David Allan Coe'),
#   (0.1453531416409055, 'Positive Touch', 'Journey'),
#   (0.14506803753702938, 'Help It Along', 'Cliff Richard'),
#   (0.1449123520989609, 'Athena', 'Who'),
#   (0.14403817006813682, 'Own The Night', 'Chaka Khan'),
#   (0.14186499256896434, 'Where I End And You Begin', 'Radiohead'),
#   (0.14043608759680523, 'Cowboy Cadillac', 'Garth Brooks'),
#   (0.14011996068963026, 'D.O.A.', 'Van Halen'),
#   (0.13960927224824696, 'Down The Road', 'Kenny Chesney'),
#   (0.13935908982220319, "Ain't No Sunshine", 'Bill Withers'),
#   (0.1368665370842066, 'Midnight Queen', 'Nickelback'),
#   (0.13626684295031719, 'There She Goes Again', 'Velvet Underground'),
#   (0.13599411212523255, "Dancin' For The Groceries", 'Kenny Chesney'),
#   (0.13339889661834034, "Ain't No Sunshine When She's Gone", 'Bob Marley'),
#   (0.13272862662889934, 'Too Good To Be True', 'Nitty Gritty Dirt Band'),
#   (0.13213448163315852, 'I Wanna Stay Alive With You', 'Ocean Colour Scene'),
#   (0.13068421067260202, 'Bridge Over Troubled Water', 'Michael W. Smith'),
#   (0.1295782840952205, 'Hotdog In A Hallway', 'NOFX'),
#   (0.12878169590043184, 'Help', 'Dolly Parton'),
#   (0.12705781655596413, "Help Me Thro' The Day", 'Whitesnake'),
#   (0.12646400194438775, 'Baby Boy', 'Status Quo'),
#   (0.12609264220748112, 'Wonderful', 'Christina Perri'),
#   (0.12467419316866393, "I Don't Care Anymore", 'Phil Collins'),
#   (0.12397981142716231, 'Tell Me A Story', 'Iggy Pop')],
#  'Forever Autumn': [(0.3152141553030351, 'Autumn', 'Barbra Streisand'),
#   (0.1826702529051424, 'The One.', 'Foo Fighters'),
#   (0.16598816614017747, 'Love At First Sight', 'Kylie Minogue'),
#   (0.16570924870896717, 'Seven Years', 'Norah Jones'),
#   (0.164535176828964, 'Sweet Isabel', 'Enrique Iglesias'),
#   (0.15230825095599865, 'Killing Me Softly', 'Luther Vandross'),
#   (0.1519897772840638, 'When I Close My Eyes', 'Kenny Chesney'),
#   (0.15125590450444748, 'Smile', 'Incognito'),
#   (0.1470282117928042, "You're On Your Own", 'Alan Parsons Project'),
#   (0.13961448191621445, 'New Dream Islands (Session Outtake)', 'Pat Benatar'),
#   (0.13577080361862215, 'Our Love', 'Natalie Cole'),
#   (0.13474352159335132, 'It Had To Be You', 'Kenny Rogers'),
#   (0.13224967052716022, 'Fireball', 'Deep Purple'),
#   (0.13131813041075713, 'King Of Trees', 'Cat Stevens'),
#   (0.13054113908829937, 'Raking Up Leaves', 'Tom T. Hall'),
#   (0.12610020106143574, 'The Only One', 'Yngwie Malmsteen'),
#   (0.1260753111375741, 'Someone That I Used To Love', 'Natalie Cole'),
#   (0.12291750075920643, 'Amazing', 'Inna'),
#   (0.12226861487470725, 'I Want You To Know', 'Planetshakers'),
#   (0.12154387008404383, 'Every Year Every Christmas', 'Luther Vandross'),
#   (0.12117461599756305, 'I Get A Kick Out Of You', 'Billie Holiday'),
#   (0.12069189018462163, 'North And South Of The River', 'Christy Moore'),
#   (0.11981759108699713, "Now's The Time", 'David Allan Coe'),
#   (0.11956640700374359, "You're No Good", 'Wilson Phillips'),
#   (0.11937423648497178, 'All My Life', 'Kenny Rogers'),
#   (0.1190999506225628, "It's Growing", 'Otis Redding'),
#   (0.11707069844873573, 'Angel', 'Lionel Richie'),
#   (0.11672493287771876, "It's Growing", 'The Temptations'),
#   (0.11662531872957488, 'Is It Already Time', 'George Strait'),
#   (0.11656340249792718, 'Lucky Ones', 'Lana Del Rey'),
#   (0.1165509691316131, 'Winter Clothes', 'John McDermott'),
#   (0.11654888573923383, 'I Still Remember', 'Gary Numan'),
#   (0.11637419627817489, 'Donegal Breeze', 'Mary Black'),
#   (0.11622379281667748, 'December Snow', 'Moody Blues'),
#   (0.11497639688390432, 'Going To The Top', 'John Waite'),
#   (0.11469740737581154, 'Coins In A Fountain', 'Passenger'),
#   (0.1132143640001126, 'I Guess I Like It Like That', 'Kylie Minogue'),
#   (0.11312788332811306, 'At My Window', 'Beach Boys'),
#   (0.11299289900370152, 'The Game Is Over', "'n Sync"),
#   (0.11274514893460903, 'Always On Time', 'Kyla'),
#   (0.11217903244928679, 'Lonely Days', 'Oliver'),
#   (0.11160160828282235, 'Rain Or Shine', 'Vonda Shepard'),
#   (0.11143639295397618, 'Double E', 'Neil Young'),
#   (0.11123170163014004, 'Blue Skies', 'Point Of Grace'),
#   (0.10986891080626399, 'Man Of The Year', 'Alice Cooper'),
#   (0.10934087595562367, 'Down Home Girl', 'Nazareth'),
#   (0.1090896973564186, 'Never Be Lonely', 'America'),
#   (0.10882997933680989, 'Colder', 'Travis')],
#  'Nothing But A Child': [(0.351594606411314, 'Smile', 'Incognito'),
#   (0.3425102752520581, 'No Child Of Mine', 'Marianne Faithfull'),
#   (0.3114751691588529, 'Shake My Tree', 'Whitesnake'),
#   (0.27998974646589725, 'Love Child', 'Diana Ross'),
#   (0.26728670454350933, 'Child Come Away', 'Kim Wilde'),
#   (0.226940792133359, 'When A Child Is Born', 'Boney M.'),
#   (0.20898656771447172, 'Voodoo Child', 'Jimi Hendrix'),
#   (0.20255902532782116, 'Dead Man Walking', 'David Bowie'),
#   (0.19152913062068183, "I'm Gonna Cry (Cry Baby)", 'Wilson Pickett'),
#   (0.18077761943909093, "I'm Not Your Baby", 'U2'),
#   (0.17617184604496547, 'She Called Me Baby', 'Glen Campbell'),
#   (0.1746119214430748, 'He Called Me Baby', 'Patsy Cline'),
#   (0.1716410961323403, 'Ave Mary A', 'P!nk'),
#   (0.17135367769298995, 'Children Of The Damned', 'Iron Maiden'),
#   (0.16869857238042996, 'Sorry', 'Stevie Wonder'),
#   (0.16840511853040266, 'Disco Inferno', 'Cyndi Lauper'),
#   (0.16785397558682183, 'Secret Love', 'Mariah Carey'),
#   (0.16557117535903304, 'Cry Cry Cry', 'Steve Miller Band'),
#   (0.16545574110884498, 'One And Only', 'Mary Black'),
#   (0.16389317451009938, "You're No Good", 'Wilson Phillips'),
#   (0.16368198084221205, "You're On Your Own", 'Alan Parsons Project'),
#   (0.16273506626896572, 'Baby One More Time', 'Glee'),
#   (0.16152685372908188, 'The One.', 'Foo Fighters'),
#   (0.1607903245874013, 'No Blue Skies', 'Lloyd Cole'),
#   (0.15931931748397135, 'Flying On The Ground (Is Wrong)', 'Neil Young'),
#   (0.15854693111474166, 'Baby Me Baby', 'Barbra Streisand'),
#   (0.1578796438662652, 'Close My Eyes', 'Mariah Carey'),
#   (0.15753638579416349, "You Don't Love Me", 'Allman Brothers Band'),
#   (0.15403181733035087, 'Come And Go Blues', 'Allman Brothers Band'),
#   (0.15398321686136934, 'I Can Make It Better', 'Luther Vandross'),
#   (0.15341983336605322, 'Cry Baby', 'Cheap Trick'),
#   (0.1528426451490988, 'Please, Please, Please', 'Who'),
#   (0.15136890001118308, 'I Know Very Well How I Got My Name', 'Morrissey'),
#   (0.14742697718684275,
#    "I'm Gonna Sit Right Down And Write Myself A Letter",
#    'Perry Como'),
#   (0.1473491197960092, 'What You Are', 'Lionel Richie'),
#   (0.1465896382227366, "Didn't Leave Nothing But The Baby", 'Emmylou Harris'),
#   (0.14568425068209964, 'Life Is Beautiful', 'Noa'),
#   (0.14172856952327167, 'All Screwed Up', 'Ramones'),
#   (0.14055724485497215, "She's So Beautiful", 'Genesis'),
#   (0.13957928617729853, 'Too Funky', 'George Michael'),
#   (0.1360545241546129, 'My Heart... So Blue', 'Erasure'),
#   (0.13509928056027554, 'Thank You For Sending Me An Angel', 'Talking Heads'),
#   (0.1350393884133418, 'Diet Mountain Dew', 'Lana Del Rey'),
#   (0.13481779513938613, 'Redondo Beach', 'Patti Smith'),
#   (0.1345800901687476, 'Complicated', 'Face To Face'),
#   (0.13395521560007465, "Can't Take My Eyes Off You", 'Frankie Valli'),
#   (0.13369397365579105, 'Baby Blue', 'Beach Boys'),
#   (0.13365265822470612, 'Into My Arms', 'Nick Cave')],
#  'Come To Praise': [(0.5183092498925174,
#    'Give Him Praise',
#    'Indiana Bible College'),
#   (0.3580975335272505, 'Great In Power', 'Hillsong United'),
#   (0.2487452406817771, 'I Saw The Light', 'Emmylou Harris'),
#   (0.236649813100471, 'I Simply Live For You', 'Hillsong United'),
#   (0.22036250474384594, 'I Saw The Light', 'Wanda Jackson'),
#   (0.19697531936204732, 'From The Inside Out', 'Hillsong United'),
#   (0.17212070777470637, 'So Amazing', 'Indiana Bible College'),
#   (0.1638244694295625, 'I Live To Know You', 'Hillsong'),
#   (0.15395818517935891, 'Because Of Who You Are', 'Imperials'),
#   (0.14690385136666873, 'Jesus Saves', 'Slayer'),
#   (0.14640758739668838, 'Glorious', 'Hillsong'),
#   (0.14333133167557655, 'Jesus Is The Reason For The Season', 'Kirk Franklin'),
#   (0.14135383364468357, 'Everything To Me', 'Hillsong United'),
#   (0.1367883268578233, '(Everybody) Get Down', 'Gary Valenciano'),
#   (0.13319399200508628, 'Welcome Into This Place', 'Planetshakers'),
#   (0.12847893037347127, 'Once You Get Started', 'Chaka Khan'),
#   (0.12353565797284172, 'Different Now', 'Out Of Eden'),
#   (0.11808446894418971, 'Sing For Me', 'Yellowcard'),
#   (0.11620491721437652, 'Come On Back', 'Hollies'),
#   (0.11422383765972438, "Steel Drivin' Man", 'Arrogant Worms'),
#   (0.11402325958451479, 'Just A Name', 'Cher'),
#   (0.11324481893651146, 'I Wanna Get Back With You', 'Tori Amos'),
#   (0.11286162392200745, 'A Love Song', 'Kenny Loggins'),
#   (0.11240519163764084, 'Who Do You Think You Are', 'Kim Wilde'),
#   (0.11085387324853901, 'Thank You For The Music', 'ABBA'),
#   (0.10995789434722394, 'I Need Love', 'Bonnie Raitt'),
#   (0.10728379693597356, 'I Want To Know What Love Is', 'Mariah Carey'),
#   (0.10470106059824133, 'Just A Friend', 'Usher'),
#   (0.10313945270054424, "I'm Gonna Sing You A Sad Song", 'Kenny Rogers'),
#   (0.10306285799733375, 'Everybody Hurts', 'Glee'),
#   (0.10279837404476638, 'Power To Love', 'Ray Boltz'),
#   (0.10270662538871823, 'SOMETHING GOT A HOLD OF ME', 'Hank Williams'),
#   (0.10217242654106834, 'Closer', 'Westlife'),
#   (0.10205403857217503, "Don't Give Up On Each Other", 'Diana Ross'),
#   (0.10203839489111818, 'Flame Still Burns', 'Youth Of Today'),
#   (0.1019367444237618, 'In Love With You', 'Regine Velasquez'),
#   (0.10027284619990696, "I'll Find You", 'Air Supply'),
#   (0.09935384004068726, 'Gotta Get A Message To You', 'Bee Gees'),
#   (0.09908910352639913, 'Is It Love', 'Bette Midler'),
#   (0.09873086458503194, 'Plain Gold Ring', 'Nick Cave'),
#   (0.09845742340816765, 'We Will Be Together', 'Regine Velasquez'),
#   (0.09787423698580941, "Sing Redemption's Song", 'Israel Houghton'),
#   (0.0974063167931886, 'Just As I Am', 'Air Supply'),
#   (0.09702299752959231, 'I Am Your Singer', 'Paul McCartney'),
#   (0.0969627589616158, 'Heed The Call', 'Kenny Rogers'),
#   (0.09652812226298495, 'If There Is Music There', 'Donna Summer'),
#   (0.09647532258612625, 'Original Doll', 'Britney Spears'),
#   (0.09647317208751627, 'Virgin', 'Spandau Ballet')],
#  'House On The Ocean': [(0.40033055479875435,
#    'Learn To Say Goodbye',
#    'Dusty Springfield'),
#   (0.3764482844979193, 'Immortality', 'Bee Gees'),
#   (0.37363521213843365, 'Seconds', 'U2'),
#   (0.3443414166637113, 'Never Say Die', 'Ozzy Osbourne'),
#   (0.3324848375359874, 'Not The One', 'Zoegirl'),
#   (0.3280239000574841, 'Try It Baby', 'The Temptations'),
#   (0.3096560098462984, 'Goodbye', 'Inna'),
#   (0.30814873053806624, 'Goodbye In Her Eyes', 'Zac Brown Band'),
#   (0.30015256921637073, "I Don't Want To Do It", 'George Harrison'),
#   (0.29210358820337673, "What's So Good About Goodbye?", 'The Temptations'),
#   (0.28412902864494927, 'Goodbye', 'Air Supply'),
#   (0.2825450925847263, 'Suite-Pee', 'System Of A Down'),
#   (0.28140752834376914, 'Try Too Hard', 'P!nk'),
#   (0.2811819609648875, 'Half A Man', 'America'),
#   (0.279171127080149, 'I Know You Well', 'Face To Face'),
#   (0.2766432291838466, "I Don't Care", 'Quincy Punx'),
#   (0.27428572777629023, "Baby Don't You Know?", 'Dusty Springfield'),
#   (0.2595719444640987, 'This I Love', "Guns N' Roses"),
#   (0.24755665933574747, 'Goodbye', 'Emmylou Harris'),
#   (0.2437279335869422, 'So Hard', 'Pet Shop Boys'),
#   (0.24013220627991444, 'You Are Not Alone', 'Eagles'),
#   (0.2382488492224628, 'How Many Say I', 'Van Halen'),
#   (0.23781463173266415, 'Kiss Your Past Good-Bye', 'Aerosmith'),
#   (0.23657676031427102, 'Too Numb To Cry', 'Zakk Wylde'),
#   (0.23367306621060036, 'Goodbye To Love', 'Carpenters'),
#   (0.22588554544321168, 'Hello Goodbye', 'Paul McCartney'),
#   (0.22304725527053798, 'Cosmic', 'Kylie Minogue'),
#   (0.22191624681912736, 'Alabama Song', 'Doors'),
#   (0.21727126525331433, "Say You'll Be Mine", 'Hollies'),
#   (0.21613364040202268, 'You And Me Together', 'Miley Cyrus'),
#   (0.21379014568171315, 'The One.', 'Foo Fighters'),
#   (0.21052371488564844, 'Oh Me, Oh My Sweet Baby', 'George Strait'),
#   (0.2066082763786029, "Don't Speak Of Love", 'Dusty Springfield'),
#   (0.2041440940117333, 'Gloria', 'U2'),
#   (0.2007840139027306, "Please Don't Make Me Cry", 'UB40'),
#   (0.19967133380199398, 'Get Down, Make Love', 'Nine Inch Nails'),
#   (0.19821481202336433, 'Walking In My Shoes', 'Depeche Mode'),
#   (0.1949108768063355, 'Till The Day I Die', 'Whitesnake'),
#   (0.19432284129725325,
#    "I Don't Love You Anymore (duet With Lea Salonga)",
#    'Ariel Rivera'),
#   (0.19368401650662956, 'Come Back Darling', 'UB40'),
#   (0.19367222284775204, 'Complicated', 'Face To Face'),
#   (0.1914108783437264, 'Look On Down From The Bridge', 'Mazzy Star'),
#   (0.19047676071099082, "Don't", 'Elvis Presley'),
#   (0.1859026661495789, 'Turn Me Loose', 'Vince Gill'),
#   (0.18523464787092236, 'Girls Love Beyonce', 'Drake'),
#   (0.1834674065164117, 'All I Ever Wanted', 'Human League'),
#   (0.18276834517659304, 'Rock Star', 'Britney Spears'),
#   (0.18220517536200947, 'Leaves That Are Green', 'Paul Simon')],
#  'Oh Boy!': [(0.31068873622317733, 'Baby Boy', 'Status Quo'),
#   (0.27859464663852557, 'One Boy Girl', 'Kylie Minogue'),
#   (0.258623599535015, 'Silly Boy', 'Rihanna'),
#   (0.25554683503798564, 'Boy From The Block', 'Gucci Mane'),
#   (0.2288629511635572, 'Summer Boy', 'Lady Gaga'),
#   (0.20733476682468452, 'Never Named', 'Soundgarden'),
#   (0.20431436445196227, 'Still On It', 'Young Jeezy'),
#   (0.20420002970435563, 'Home', 'Iggy Pop'),
#   (0.2024693019422234, 'Gangsta Party', 'Yo Gotti'),
#   (0.19450649280414078, 'Coulda Been The One', 'Rihanna'),
#   (0.18970833042804985, 'Girls And Boys', 'Pet Shop Boys'),
#   (0.18427042615247238, "It's Alright", 'Chicago'),
#   (0.18197055159406325, 'Uh Oh', 'Justin Bieber'),
#   (0.18081332857062898, 'Obsessed', 'Mariah Carey'),
#   (0.18073928156774433, 'Please, Please, Please', 'Stevie Wonder'),
#   (0.17776708504290217, 'Search And Destroy', 'Iggy Pop'),
#   (0.17458099519367679, 'Dreams And Nightmares', 'Lil Wayne'),
#   (0.17416496706131582, 'Smile', 'Avril Lavigne'),
#   (0.1676969623605318, "I'm Threw Witchu", 'Snoop Dogg'),
#   (0.16515834111207722, 'Like A Virgin', 'Marilyn Manson'),
#   (0.16433465412581186, 'I Might Be', 'Gucci Mane'),
#   (0.1633423426474308, 'Ancient Train', 'Travis'),
#   (0.16169520600210577, 'Come On', 'Lil Wayne'),
#   (0.16167459505887544, 'Flinstone Boy', 'Elton John'),
#   (0.15401694721755715, 'Look At The Fool', 'Tim Buckley'),
#   (0.15278975575106632, 'Land Of The Snakes', 'J Cole'),
#   (0.14895917321448715, 'My Eye On You', 'Bette Midler'),
#   (0.14841826199272992, 'Highway', 'Paul McCartney'),
#   (0.1474325790174138, 'Fly Out', 'Lil Wayne'),
#   (0.14693737454539127, 'Bad Boy', 'Eric Clapton'),
#   (0.1458549693845127, 'You Had To Be There', 'Tim McGraw'),
#   (0.14531013662133574, 'Curtains', 'Lil Wayne'),
#   (0.14378517863074114, 'Oh Me, Oh My Sweet Baby', 'George Strait'),
#   (0.14328804590718347, 'Merry Christmas, Baby', 'Christina Aguilera'),
#   (0.14234896650257675, 'Are You Real?', 'Gary Numan'),
#   (0.14131827605145805, "Keep It Comin'", 'Uncle Kracker'),
#   (0.14052899975063463, 'Real Good Man', 'Tim McGraw'),
#   (0.14022415646895664,
#    'If You Were The Only Girl In The World',
#    'Dean Martin'),
#   (0.13940129409857493, 'Brand New', 'Lil Wayne'),
#   (0.13864508248436935, 'Oh Woman', 'Reo Speedwagon'),
#   (0.13793404760137754, 'Keep It Playa', 'Pharrell Williams'),
#   (0.1379302152288109, 'New York Gangstas', 'LL Cool J'),
#   (0.13787975230361108, 'Action', 'Lil Wayne'),
#   (0.13617545445041915, 'Just A Dream', 'Youngbloodz'),
#   (0.13520545127643094, 'Golden Girl', 'Rihanna'),
#   (0.13510695473737902, 'French Song', 'The Monkees'),
#   (0.13478131165580504, 'Cash Money Millionaires', 'Lil Wayne'),
#   (0.13389833308504545, 'Imma Do It', 'Fabolous')],
#  ...}

# %%
# Display first element in dictionary
pprint(list(similarities.items())[test_song])
# Out:
# ('At My Window',
#  [(0.28144560509684935, 'Fly Away', 'Bread'),
#   (0.23304202139944036, 'Angel', 'Rod Stewart'),
#   (0.18285653312926614, 'Down Came The World', 'Waylon Jennings'),
#   (0.17988040427774896, 'Beautiful Bluebird (2007)', 'Neil Young'),
#   (0.17959373689321043, 'Knock On Any Door', 'Jackson Browne'),
#   (0.15855507637869912, 'Blackbird', 'Nina Simone'),
#   (0.15618374260182297, "Rain Keeps Fallin'", 'Grand Funk Railroad'),
#   (0.1543196549392247, "God Ain't No Stained Glass Window", 'Johnny Cash'),
#   (0.1436789745824404, 'Since Jesus Came Into My Heart', 'Randy Travis'),
#   (0.138038438920131, 'Dirty Blvd.', 'Lou Reed'),
#   (0.13684450790987995, 'Remember When', 'Leann Rimes'),
#   (0.12835271574360788, 'Little Girl', 'Reba Mcentire'),
#   (0.11910419896802356, 'All My Love', 'Cliff Richard'),
#   (0.11895918729169286, "I'm Alive", 'Celine Dion'),
#   (0.11883601516080641, 'Lab Monkey', 'Alice In Chains'),
#   (0.11663771852263205, 'Come In With The Rain', 'Demi Lovato'),
#   (0.11650670336546978, 'Beautiful Bluebird', 'Neil Young'),
#   (0.11501507976143599, 'Fly To Moscow', 'Modern Talking'),
#   (0.1140201965670999, 'Day Too Soon', 'Sia'),
#   (0.11312788332811306, 'Forever Autumn', 'Moody Blues'),
#   (0.11139048897004965, 'You Can Have Him', 'Irving Berlin'),
#   (0.11047858160492253, 'Flying Machine', 'Cliff Richard'),
#   (0.11013730761385467, 'Faster', 'Within Temptation'),
#   (0.1079555949145013, 'Over The Rainbow', 'Harry Connick, Jr.'),
#   (0.10605233412093067, "Don't Look Away", 'Who'),
#   (0.10468842843492546, 'Right Away', 'Styx'),
#   (0.10357335918492253, 'Ring Out The Bell', 'Travis'),
#   (0.10204172525278632, 'Heavy', 'Train'),
#   (0.10147392665549737, 'There She Goes Again', 'Velvet Underground'),
#   (0.10143803112132989, 'Velcro Fly', 'ZZ Top'),
#   (0.1013758018826638, 'No One Can', 'Marillion'),
#   (0.10010317528432292, 'Over The Rainbow', 'Matt Monro'),
#   (0.09879387582002984, 'Birds', 'Neil Young'),
#   (0.09801228692821813, 'Light Up The Sky', 'Christina Aguilera'),
#   (0.0956685521370257, 'Home', 'Mary Black'),
#   (0.09534363493891798, 'Dead Man Walking', 'David Bowie'),
#   (0.094822431143472, 'Find Your Self, Discover God', 'Orphaned Land'),
#   (0.09440639421439286, 'Seasons', 'America'),
#   (0.09310492585893407, 'Private Heaven', 'Utopia'),
#   (0.09231416972555499, 'On Broken Wings', 'Europe'),
#   (0.09062203603632006, 'Beautiful Mystery', 'Owl City'),
#   (0.08640682799315304, "Charlie's Medicine", 'Warren Zevon'),
#   (0.08618916142909815, 'Juarez', 'Tori Amos'),
#   (0.08507532714353298, 'Eleanor Rigby', 'John Denver'),
#   (0.08502440677842049, 'Best Years', 'Whitesnake'),
#   (0.08499420744388235, 'Beady Eyed Buzzard', 'Perry Como'),
#   (0.0846376008946761,
#    "I'm Gonna Sit Right Down And Write Myself A Letter",
#    'Perry Como'),
#   (0.0844574193715466, 'Mama Told Me Not To Come', 'Wilson Pickett')])

# %% [markdown]
# ### Create song recommender

# %%
# Use the similarity scores (generated above) to access the most similar items and make recommendations
# Create Content based recommender class
class ContentBasedRecommender:
    def __init__(self, matrix):
        self.matrix_similar = matrix

    def _print_songs(self, song, recom_songs):
        rec_items = len(recom_songs)
        
        print(f'The {rec_items} recommended songs for {song} are:')
        for i in range(rec_items):
            print(f"\t{i+1}: {recom_songs[i][1]} by {recom_songs[i][2]} (with {round(recom_songs[i][0], 3)}" +
                   " similarity score)")
        
    def recommend(self, song, rec_num_songs=3):
        recom_songs = self.matrix_similar[song][:rec_num_songs]
        # Print each recommend song
        self._print_songs(song=song, recom_songs=recom_songs)

# %%
# Instantiate Content based recommender class with the precomputed similarities
recommedations = ContentBasedRecommender(similarities)

# %% [markdown]
# ### Make song recommendations

# %%
# Pick a song and make a recommendation
recommedations.recommend(songs['song'].iloc[10])
# Out:
# The 3 recommended songs for I've Got A Pocketful Of Dreams are:
# 	1: I Feel Lucky by Pat Benatar (with 0.19 similarity score)
# 	2: Lucky Me by Chris Brown (with 0.177 similarity score)
# 	3: One Life by Kenny Rogers (with 0.174 similarity score)

# %%
# Pick another song and make a recommendation
recommedations.recommend(songs['song'].iloc[120], 5)
# Out:
# The 5 recommended songs for Try It Baby are:
# 	1: Not The One by Zoegirl (with 0.393 similarity score)
# 	2: All Screwed Up by Ramones (with 0.356 similarity score)
# 	3: I Know You Well by Face To Face (with 0.353 similarity score)
# 	4: Do It To Me by Lionel Richie (with 0.341 similarity score)
# 	5: Cry Baby by Cheap Trick (with 0.334 similarity score)
